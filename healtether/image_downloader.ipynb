# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam92211/Computer-Vision/blob/main/healtether/image_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install bing-image-downloader

# %%
! mkdir images

# %%
from bing_image_downloader import downloader

downloader.download("melanoma", limit=20,  output_dir='images',)
# Out:
# [%] Downloading Images to /content/images/melanoma
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://assets.cureus.com/uploads/figure/file/22171/lightbox_0c869bf094d611e7956b9d08b856c5fb-Linear-Skin-Cancers---Panel-3.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://miiskin.com/wp-content/uploads/guide-melanoma-symptoms-signs-infographic.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://health.clevelandclinic.org/wp-content/uploads/sites/3/2015/09/Melanoma.jpg
# [Error]Invalid image, not saving https://health.clevelandclinic.org/wp-content/uploads/sites/3/2015/09/Melanoma.jpg
#
# [!] Issue getting: https://health.clevelandclinic.org/wp-content/uploads/sites/3/2015/09/Melanoma.jpg
# [!] Error:: Invalid image, not saving https://health.clevelandclinic.org/wp-content/uploads/sites/3/2015/09/Melanoma.jpg
#
# ...

# %%
import os
import pandas as pd

# Folder containing the images
folder_path = 'images/melanoma'

# List all files in the folder
image_files = os.listdir(folder_path)

# Filter only for image files (if needed)
image_files = [file for file in image_files if file.endswith('.jpg') or file.endswith('.png')]

# Create a DataFrame with the file names
data = pd.DataFrame({'Image File': image_files})

# Save the DataFrame to a CSV file
data.to_csv('image_files.csv', index=False)

# %%
import torch
from torch.utils.data import Dataset
from skimage import io

# %%
class Skin(Dataset):

  def __init__(self, csv_file, root_dir, transform=None):
    self.annotations = pd.read_csv(csv_file)
    self.root_dir = root_dir
    self.transform = transform

  def __len__(self):
    return len(self.annotation)

  def __getitem__(self, index):
    img_path = os.path.join(self.root_dir, self.annotations.iloc[index, 0])
    image = io.imread(img_path)
    # y_label = torch.tensor(int(self.annotations.iloc[index, 1]))

    if self.transform:
      image = self.transform(image)

    return (image)

# %%
import torchvision.transforms as transforms

dataset = Skin(csv_file='image_files.csv', root_dir='', transform = transforms.ToTensor())

# %%
import pandas as pd

df = pd.read_csv('image_files.csv')

df.head()
# Out:
#      Image File
# 0  Image_13.jpg
# 1  Image_14.jpg
# 2  Image_12.jpg
# 3   Image_3.jpg
# 4   Image_2.jpg
